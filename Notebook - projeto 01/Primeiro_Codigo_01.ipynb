# %% [markdown]
# #CENTRO DE EDUCAÇÃO TECNOLÓGICA DO AMAZONAS - IBC
# ##Manaus, 17 de março de 2026
#
# Alunos(as): Ashley Rhayssa Pinheiro Bezerra
# e Jessica Jatahy De Melo Fonseca

# %% [markdown]
# O texto pode ficar em **negrito**
#
# O texto também pode ficar em *itálico*
#
# Ou mesmo com a fonte ~riscada~

# %%
print("Hello World")
# Out:
# Hello World

# %%
import time
print(time.ctime())

# %%
s = 1
time.sleep(s)
print(time.ctime())

# %% [markdown]
# $\sqrt{3x-1}+(1+x)^2$

# %% [markdown]
# $e^x=\sum_{1=0}^\infty \frac{1}{i!}x^i$

# %% [markdown]
# #**Expressões Matemáticas Básicas**

# %%
print(f"10 + 5 = {10 + 5}") #Soma
print(f"10 - 5 = {10 - 5}") #Subtração
print(f"10 * 5 = {10 * 5}") #Multiplicação
print(f"50 / 2 = {50 / 2}") #Divisão
print(f"10 // 3 = {10 // 3}") #Divisão inteira
print(f"2 ** 3 = {2 ** 3}") #Potenciação
print(f"10 % 3 = {10 % 3}") #Módulo
print(f"10 ** 0.5 = {10 ** 0.5}") #Raiz quadrada
# Out:
# 10 + 5 = 15
# 10 - 5 = 5
# 10 * 5 = 50
# 50 / 2 = 25.0
# 10 // 3 = 3
# 2 ** 3 = 8
# 10 % 3 = 1
# 10 ** 0.5 = 3.1622776601683795
